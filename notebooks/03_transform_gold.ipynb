# %%
from pyspark.sql.functions import (
    col, count, avg, min, max, collect_set, explode,
    when, current_timestamp, percent_rank
)
from pyspark.sql import Window

# FACT_RATINGS — optimized for ML training
df_fact_ratings = (
    spark.table("workspace.silver.ratings")
    .select("userId", "movieId", "rating", "timestamp")
)

df_fact_ratings.write.format("delta").mode("overwrite").saveAsTable("workspace.gold.fact_ratings")
print(f"✅ Gold fact_ratings: {spark.table('workspace.gold.fact_ratings').count()} rows")

# DIM_USERS — user behavior profiles
df_dim_users = (
    spark.table("workspace.silver.ratings")
    .groupBy("userId")
    .agg(
        count("rating").alias("total_ratings"),
        avg("rating").alias("avg_rating"),
        min("timestamp").alias("first_rating"),
        max("timestamp").alias("last_rating"),
        count(when(col("rating") >= 4.0, True)).alias("high_ratings_count"),
    )
    .withColumn(
        "rating_percentile",
        percent_rank().over(Window.orderBy("total_ratings"))
    )
    .withColumn(
        "is_power_user",
        when(col("rating_percentile") >= 0.90, True).otherwise(False)  # top 10%
    )
)

df_dim_users.write.format("delta").mode("overwrite").saveAsTable("workspace.gold.dim_users")
print(f"✅ Gold dim_users: {spark.table('workspace.gold.dim_users').count()} rows")

# DIM_MOVIES_ENRICHED — movie details
df_movies = spark.table("workspace.silver.movies_enriched")

df_movie_stats = ( # Add aggregate rating info per movie
    spark.table("workspace.silver.ratings")
    .groupBy("movieId")
    .agg(
        count("rating").alias("rating_count"),
        avg("rating").alias("avg_rating")
    )
)

df_dim_movies = (
    df_movies
    .join(df_movie_stats, on="movieId", how="left")
    .fillna({"rating_count": 0, "avg_rating": 0.0})
)

df_dim_movies.write.format("delta").mode("overwrite").saveAsTable("workspace.gold.dim_movies_enriched")
print(f"✅ Gold dim_movies_enriched: {spark.table('workspace.gold.dim_movies_enriched').count()} rows")
# Out:
# ✅ Gold fact_ratings: 32000204 rows
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1134: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# ✅ Gold dim_users: 200948 rows
# ✅ Gold dim_movies_enriched: 32000204 rows

# %%
# SAMPLE QUERIES — test the Gold layer
print("\n--- Top 10 Power Users ---")
spark.table("workspace.gold.dim_users").filter("is_power_user = true").orderBy(col("total_ratings").desc()).show(10)

print("\n--- Top 10 Highest Rated Movies (min 50 ratings) ---")
spark.table("workspace.gold.dim_movies_enriched").filter("rating_count >= 50").orderBy(col("avg_rating").desc()).show(10, truncate=False)
# Out:
# --- Top 10 Power Users ---
# +------+-------------+------------------+-------------------+-------------------+------------------+------------------+-------------+
# |userId|total_ratings|        avg_rating|       first_rating|        last_rating|high_ratings_count| rating_percentile|is_power_user|
# +------+-------------+------------------+-------------------+-------------------+------------------+------------------+-------------+
# |175325|        33332| 3.077808112324493|2015-12-15 06:59:27|2020-06-12 15:35:00|              4852|               1.0|         true|
# | 17035|         9577|2.5678187323796595|2012-12-13 02:21:42|2023-10-12 12:00:17|               934|0.9999950235634272|         true|
# | 55653|         9178|3.2802898234909565|2001-08-05 18:10:38|2015-12-24 20:44:49|              2374|0.9999900471268544|         true|
# |123465|         9044| 2.528858911985847|2010-11-28 02:03:36|2023-10-12 17:01:35|              1834|0.9999850706902815|         true|
# |171795|         9016|3.1819543034605147|2009-04-07 02:50:08|2021-01-03 01:32:28|               888|0.9999800942537087|         true|
# | 10202|         7748| 3.411654620547238|2001-09-10 15:15:01|2023-10-11 10:43:36|              3154|0.9999751178171359|         true|
# |198515|         7594| 2.822754806426126|2002-07-05 04:57:01|2023-10-13 01:16:40|              1337|0.9999701413805631|         true|
# | 49305|         7488|3.2088675213675213|2006-10-10 06:41:32|2015-02-12 06:35:57|              2495|0.9999651649439902|         true|
# | 22744|         7372|2.6401926207270754|2019-03-26 13:39:49|2021-01-15 01:23:56|              1839|0.9999601885074174|         true|
# |  7858|         7322|1.5498497678229992|2000-04-07 13:13:16|2023-10-12 00:29:11|               718|0.9999552120708446|         true|
# +------+-------------+------------------+-------------------+-------------------+------------------+------------------+-------------+
# only showing top 10 rows
#
# --- Top 10 Highest Rated Movies (min 50 ratings) ---
# +-------+------+------+-------------------+----------------------+-----------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------+
# |movieId|userId|rating|timestamp          |title                 |genres     |genres_array |tags_array                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |rating_count|avg_rating        |
# +-------+------+------+-------------------+----------------------+-----------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------+
# |171011 |137613|5.0   |2017-07-18 00:32:18|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |144674|5.0   |2020-03-07 02:05:34|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |138959|5.0   |2017-12-25 10:29:00|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |132910|4.0   |2018-10-15 02:56:25|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |128177|5.0   |2020-03-30 22:05:00|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |147057|4.0   |2023-01-10 17:42:02|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |138940|4.0   |2019-04-10 21:31:23|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |150087|3.5   |2020-07-14 07:56:21|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |127547|4.5   |2017-04-19 12:02:20|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# |171011 |143243|5.0   |2017-10-11 13:29:15|Planet Earth II (2016)|Documentary|[Documentary]|[impossible shots, david attenborough, antonishing, not a movie, wildlife, visually appealing, nature, cinematography, bbc, story, visual, earth, documentary, biology, ecology, long, photography, narrated, watchdocumentaries, iguana, andes mountains, locusts, alps, leopard, jodhpur, madagascar, singapore, langur, namib, sloth, island, komodo dragon, macaque, jaipur, new york city, himalayas, making of, flamingo, penguins, hyena, mountains, desert, hummingbird, crab, mumbai, parkour]|1956        |4.4468302658486705|
# +-------+------+------+-------------------+----------------------+-----------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------+
# only showing top 10 rows
